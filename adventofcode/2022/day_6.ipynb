# %% [markdown]
# # Day 6

# %% [markdown]
# # Helper Function

# %%
def process_raw_input(raw_pair_list: list[str]) -> list[list[dict[str, str]]]:
	return [[{"start": int(elf.split("-")[0]), "end": int(elf.split("-")[1])} for elf in line.strip().split(",")] for line in raw_pair_list.split("\n")]

# %%
def find_marker(message: str, size: int) -> int:
	for i in range(len(message)-(size-1)):
		if len(list(number for number in message[i:i+size] if message[i:i+size].count(number) > 1)) == 0:
			return i + size

# %% [markdown]
# # Unit Tests

# %%
import unittest

class TestNotebook(unittest.TestCase):

	def test_(self):
		self.assertEqual(find_marker("mjqjpqmgbljsphdztnvjfqwrcgsmlb", 4), 7)
		self.assertEqual(find_marker("bvwbjplbgvbhsrlpgdmjqwftvncz", 4), 5)
		self.assertEqual(find_marker("nppdvjthqldpwncqszvftbrmjlhg", 4), 6)
		self.assertEqual(find_marker("nznrnfrfntjfmvfwmzdfjlvtqnbhcprsg", 4), 10)
		self.assertEqual(find_marker("zcfzfwzzqfrljwzlrfnpqdbhtmscgvjw", 4), 11)

		self.assertEqual(find_marker("mjqjpqmgbljsphdztnvjfqwrcgsmlb", 14), 19)
		self.assertEqual(find_marker("bvwbjplbgvbhsrlpgdmjqwftvncz", 14), 23)
		self.assertEqual(find_marker("nppdvjthqldpwncqszvftbrmjlhg", 14), 23)
		self.assertEqual(find_marker("nznrnfrfntjfmvfwmzdfjlvtqnbhcprsg", 14), 29)
		self.assertEqual(find_marker("zcfzfwzzqfrljwzlrfnpqdbhtmscgvjw", 14), 26)

unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_ (__main__.TestNotebook) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# OK

# %% [markdown]
# # Puzzle Solve

# %%
import os

with open("input" + os.sep + "6.txt", "r", encoding="utf-8") as input_values:
	message = input_values.read()

#  = process_raw_input()
marker = find_marker(message, 4)
message = find_marker(message, 14)

print(f"marker: {marker}")
print(f"message: {message}")
# Out:
# marker: 1850
# message: 2823
